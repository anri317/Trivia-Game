# %% [markdown]
# <a href="https://colab.research.google.com/github/anri317/Trivia-Game/blob/main/Trivia_Game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Define the questions and answers
quiz_questions = [
    {
        "question": "What is the capital of France?",
        "options": ["Berlin", "London", "Paris", "Madrid"],
        "answer": "Paris"
    },
    {
        "question": "Which planet is known as the Red Planet?",
        "options": ["Earth", "Mars", "Jupiter", "Saturn"],
        "answer": "Mars"
    },
    {
        "question": "Who wrote 'Hamlet'?",
        "options": ["Charles Dickens", "William Shakespeare", "Mark Twain", "Jane Austen"],
        "answer": "William Shakespeare"
    }
]

# Create widgets for the quiz
import ipywidgets as widgets
from IPython.display import display, clear_output

question_label = widgets.Label(value="")
option_buttons = [widgets.Button(description=option) for option in
                  quiz_questions[0]['options']]
score_label = widgets.Label(value="")

# Define the quiz logic
current_question = 0
score = 0

def update_question():
    global current_question
    question_label.value = quiz_questions[current_question]["question"]
    for i, button in enumerate(option_buttons):
        button.description = quiz_questions[current_question]["options"][i]

def check_answer(button):
    global current_question, score
    if button.description == quiz_questions[current_question]["answer"]:
        score += 1
    current_question += 1
    if current_question < len(quiz_questions):
        update_question()
    else:
        clear_output()
        score_label.value = f"Your final score is: {score}/{len(quiz_questions)}"
        display(score_label)

# Connect buttons to the check_answer function
for button in option_buttons:
    button.on_click(check_answer)

# Start the quiz
update_question()
display(question_label)
for button in option_buttons:
    display(button)
# Out:
# Label(value='Your final score is: 1/3')
